# %% [markdown]
# # My first notebook

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## initialize vector

# %%
x = np.linspace(0,2*np.pi,1000)

# %% [markdown]
# ## Plot sin function

# %%
k = 10
plt.plot(x,np.sin(k*x))
plt.show()
